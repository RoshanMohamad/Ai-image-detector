# %%
# !pip install -U transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 2.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 100.7 MB/s eta 0:00:0000:0100:01
# ...
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.57.2
#     Uninstalling transformers-4.57.2:
#       Successfully uninstalled transformers-4.57.2
# ...

# %% [markdown]
# ## Local Inference on GPU
# Model page: https://huggingface.co/umm-maybe/AI-image-detector
#
# ⚠️ If the generated code snippets do not work, please open an issue on either the [model repo](https://huggingface.co/umm-maybe/AI-image-detector)
# 			and/or on [huggingface.js](https://github.com/huggingface/huggingface.js/blob/main/packages/tasks/src/model-libraries-snippets.ts) 🙏

# %%
# Use a pipeline as a high-level helper
from transformers import pipeline

pipe = pipeline("image-classification", model="umm-maybe/AI-image-detector")
pipe("https://huggingface.co/datasets/huggingface/documentation-images/resolve/main/hub/parrots.png")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:104: UserWarning:
# Error while fetching `HF_TOKEN` secret value from your vault: 'Requesting secret HF_TOKEN timed out. Secrets can only be fetched when running from the Colab UI.'.
# You are not authenticated with the Hugging Face Hub in this notebook.
# If the error persists, please let us know by opening an issue on GitHub (https://github.com/huggingface/huggingface_hub/issues/new).
#   warnings.warn(
# config.json:   0%|          | 0.00/937 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/348M [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/240 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/347M [00:00<?, ?B/s]
# ...

# %%
# Load model directly
from transformers import AutoModel
model = AutoModel.from_pretrained("umm-maybe/AI-image-detector", dtype="auto")

# %% [markdown]
# ## Remote Inference via Inference Providers
# Ensure you have a valid **HF_TOKEN** set in your environment. You can get your token from [your settings page](https://huggingface.co/settings/tokens). Note: running this may incur charges above the free tier.
# The following Python example shows how to run the model remotely on HF Inference Providers, automatically selecting an available inference provider for you.
# For more information on how to use the Inference Providers, please refer to our [documentation and guides](https://huggingface.co/docs/inference-providers/en/index).

# %%
import os
from google.colab import userdata

# Ensure you have stored your HF_TOKEN in Colab Secrets with appropriate permissions
os.environ['HF_TOKEN'] = userdata.get('HF_TOKEN')

# %%
from google.colab import files

# This will open a file picker dialog
uploaded = files.upload()

# Get the name of the first uploaded file
if uploaded:
    uploaded_filename = list(uploaded.keys())[0]
    print(f"File '{uploaded_filename}' uploaded successfully.")
else:
    uploaded_filename = None
    print("No file was uploaded.")
# Out:
#      <input type="file" id="files-0fa41bcd-b9b8-4620-9c0e-2067e6998799" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0fa41bcd-b9b8-4620-9c0e-2067e6998799">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os
from huggingface_hub import InferenceClient

if uploaded_filename:
    client = InferenceClient(
        provider="auto",
        api_key=os.environ["HF_TOKEN"],
    )

    # Use the uploaded filename for inference
    output = client.image_classification(uploaded_filename, model="umm-maybe/AI-image-detector")
    print(output)
else:
    print("No file uploaded to perform inference.")
# Out:
# [ImageClassificationOutputElement(label='artificial', score=0.607191801071167), ImageClassificationOutputElement(label='human', score=0.392808198928833)]
